# %% [markdown]
# ### LAGOS HOUSE PRICES
# This dataset is primarily centered around the housing market of Lagos State, Nigeria in the year 2021. The data used here id from Jan 2021 to Feb. 25, 2021; capturing different areas of the state.
# The data is available as .csv file downloaded from Kaggle.
# We will anayse using Pandas Dataframe susing random sets of question for which we have to find the correct results.

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Ahmed\Desktop\python clas\Lagos Housing data\Housing sale_2.csv')

# %%
df
# Out:
#            Date         Price          Pid  \
# 0      1/2/2021  2.500000e+06        E9857
# 1      1/2/2021  3.000000e+07     17,H2630
# 2      1/2/2021  3.500000e+09  10,18,H4485
# 3      1/2/2021  3.400000e+08        H4413
# 4      1/2/2021  2.800000e+07        G8554
# ...         ...           ...          ...
# 9779  2/15/2021  5.000000e+07        E0725
# 9780  2/15/2021  4.500000e+07        E0701
# 9781  2/15/2021  3.000000e+07        E0721
# 9782  2/15/2021  4.500000e+08        E0719
# 9783  2/15/2021  2.000000e+06        E0717
#
#                                           Property_name               Area  \
# 0     Land for sale Eleranigbe Eleranigbe Ibeju-Lekk...        Ibeju-Lekki
# 1     667.0 square meter Land for sale opebi street ...              Opebi
# 2     3 bedroom House for sale Victoria Island Exten...                 VI
# 3     5 bedroom Duplex for sale Lekki Phase 1 Lekki ...              Lekki
# ...

# %%
df.count()
# Out:
# Date             9784
# Price            9784
# Pid              9784
# Property_name    9784
# Area             9784
# Address          9784
# Neighboorhood    9784
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date             0
# Price            0
# Pid              0
# Property_name    0
# Area             0
# Address          0
# Neighboorhood    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())   #no null values present
plt.show()

# %% [markdown]
# ### Question 1: Convert the datatype of 'Date' column to Date-Time format.

# %%
df.dtypes
# Out:
# Date              object
# Price            float64
# Pid               object
# Property_name     object
# Area              object
# Address           object
# Neighboorhood     object
# dtype: object

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df.dtypes
# Out:
# Date             datetime64[ns]
# Price                   float64
# Pid                      object
# Property_name            object
# Area                     object
# Address                  object
# Neighboorhood            object
# dtype: object

# %% [markdown]
# ### Question 2: Add a new column 'Year' in the dataframe, which contains year only.

# %%
df['Year'] = df.Date.dt.year

# %%
df.head()
# Out:
#         Date         Price          Pid  \
# 0 2021-01-02  2.500000e+06        E9857
# 1 2021-01-02  3.000000e+07     17,H2630
# 2 2021-01-02  3.500000e+09  10,18,H4485
# 3 2021-01-02  3.400000e+08        H4413
# 4 2021-01-02  2.800000e+07        G8554
#
#                                        Property_name           Area  \
# 0  Land for sale Eleranigbe Eleranigbe Ibeju-Lekk...    Ibeju-Lekki
# 1  667.0 square meter Land for sale opebi street ...          Opebi
# 2  3 bedroom House for sale Victoria Island Exten...             VI
# 3  5 bedroom Duplex for sale Lekki Phase 1 Lekki ...          Lekki
# 4  3 bedroom Flat / Apartment for sale Igando Iko...  Igando Ikotun
#
#                                              Address Neighboorhood  Year
# 0  Eleranigbe Eleranigbe Eleranigbe Ibeju-Lekki L...   Ibeju-Lekki  2021
# 1        Opebi street opebi street Opebi Ikeja Lagos         Ikeja  2021
# 2                     VI Lagos VI Extension VI Lagos            VI  2021
# ...

# %% [markdown]
# ### Question 3: Add a new column 'Month' as second column in the dataframe, which contains Month only.

# %%
df.insert(2, 'Month', df.Date.dt.month)

# %%
df.head()
# Out:
#         Date         Price  Month          Pid  \
# 0 2021-01-02  2.500000e+06      1        E9857
# 1 2021-01-02  3.000000e+07      1     17,H2630
# 2 2021-01-02  3.500000e+09      1  10,18,H4485
# 3 2021-01-02  3.400000e+08      1        H4413
# 4 2021-01-02  2.800000e+07      1        G8554
#
#                                        Property_name           Area  \
# 0  Land for sale Eleranigbe Eleranigbe Ibeju-Lekk...    Ibeju-Lekki
# 1  667.0 square meter Land for sale opebi street ...          Opebi
# 2  3 bedroom House for sale Victoria Island Exten...             VI
# 3  5 bedroom Duplex for sale Lekki Phase 1 Lekki ...          Lekki
# 4  3 bedroom Flat / Apartment for sale Igando Iko...  Igando Ikotun
#
#                                              Address Neighboorhood  Year
# 0  Eleranigbe Eleranigbe Eleranigbe Ibeju-Lekki L...   Ibeju-Lekki  2021
# 1        Opebi street opebi street Opebi Ikeja Lagos         Ikeja  2021
# ...

# %% [markdown]
# ### Question 4: Remove the columns 'Year' and 'Month' from the dataframe.

# %%
df.drop(['Month', 'Year'], axis=1,  inplace = True)

# %%
df.head()
# Out:
#         Date         Price          Pid  \
# 0 2021-01-02  2.500000e+06        E9857
# 1 2021-01-02  3.000000e+07     17,H2630
# 2 2021-01-02  3.500000e+09  10,18,H4485
# 3 2021-01-02  3.400000e+08        H4413
# 4 2021-01-02  2.800000e+07        G8554
#
#                                        Property_name           Area  \
# 0  Land for sale Eleranigbe Eleranigbe Ibeju-Lekk...    Ibeju-Lekki
# 1  667.0 square meter Land for sale opebi street ...          Opebi
# 2  3 bedroom House for sale Victoria Island Exten...             VI
# 3  5 bedroom Duplex for sale Lekki Phase 1 Lekki ...          Lekki
# 4  3 bedroom Flat / Apartment for sale Igando Iko...  Igando Ikotun
#
#                                              Address Neighboorhood
# 0  Eleranigbe Eleranigbe Eleranigbe Ibeju-Lekki L...   Ibeju-Lekki
# 1        Opebi street opebi street Opebi Ikeja Lagos         Ikeja
# 2                     VI Lagos VI Extension VI Lagos            VI
# ...

# %% [markdown]
# ### Question 5: Show all the records where 'Price' is  less than 3 million. And how many such records are there?

# %%
df[df.Price < 3000000]
# Out:
#            Date      Price    Pid  \
# 0    2021-01-02  2500000.0  E9857
# 14   2021-01-02  2500000.0  H1579
# 64   2021-01-02  1800000.0  H5626
# 65   2021-01-02  1800000.0  H5620
# 74   2021-01-02  1200000.0  G5264
# ...         ...        ...    ...
# 9748 2021-02-15  1500000.0  E0855
# 9750 2021-02-15  1500000.0  E0852
# 9755 2021-02-15  2000000.0  E0847
# 9770 2021-02-15  2000000.0  E0749
# 9783 2021-02-15  2000000.0  E0717
#
#                                           Property_name               Area  \
# 0     Land for sale Eleranigbe Eleranigbe Ibeju-Lekk...        Ibeju-Lekki
# 14                Land for sale Eleko Ibeju-Lekki Lagos        Ibeju-Lekki
# 64    600.0 square meter Land for sale Eluju Ibeju L...  Ibeju-Lekki Ibeju
# 65    600.0 square meter Land for sale Eluju Ibeju L...  Ibeju-Lekki Ibeju
# 74    600.0 square meter Land for sale Lepia Town Fr...  Ibeju-Lekki Ibeju
# ...                                                 ...                ...
# ...

# %%
len(df[df.Price < 3000000])
# Out:
# 771

# %% [markdown]
# ### Question 6: What is the maximum and minimum 'Price' per year in Ibeju-Lekki?

# %%
df1=df[df.Area=='Ibeju-Lekki']

# %%
df1
# Out:
#          Date         Price        Pid  \
# 0  2021-01-02  2.500000e+06      E9857
# 14 2021-01-02  2.500000e+06      H1579
# 18 2021-01-02  4.000000e+06      H4686
# 20 2021-01-02  2.500000e+07      G6335
# 31 2021-01-02  1.000000e+10  700,H4285
# 35 2021-01-02  3.000000e+06      H4272
#
#                                         Property_name         Area  \
# 0   Land for sale Eleranigbe Eleranigbe Ibeju-Lekk...  Ibeju-Lekki
# 14              Land for sale Eleko Ibeju-Lekki Lagos  Ibeju-Lekki
# 18  Land for sale Onosa Free Trade Zone Ibeju-Lekk...  Ibeju-Lekki
# 20              Land for sale Eleko Ibeju-Lekki Lagos  Ibeju-Lekki
# 31  1000.0 square meter Commercial Property for sa...  Ibeju-Lekki
# 35  1000.0 square meter Land for sale Lekki Free T...  Ibeju-Lekki
#
#                                               Address Neighboorhood
# 0   Eleranigbe Eleranigbe Eleranigbe Ibeju-Lekki L...   Ibeju-Lekki
# 14                      ELEKO Eleko Ibeju-Lekki Lagos   Ibeju-Lekki
# ...

# %%
df1.groupby('Date').Price.max() #Maximum price
# Out:
# Date
# 2021-01-02    1.000000e+10
# Name: Price, dtype: float64

# %%
df1.groupby('Date').Price.min()  #Minimum price
# Out:
# Date
# 2021-01-02    2500000.0
# Name: Price, dtype: float64

# %%
df1.groupby('Date').Price.mean()  #Mean price
# Out:
# Date
# 2021-01-02    1.672833e+09
# Name: Price, dtype: float64

# %% [markdown]
# ### Question 7: What is the maximum and minimum 'Price' recorded by area?

# %%
df.groupby('Area').Price.max().sort_values(ascending = True) #Maximum price by Area in Ascending Order
# Out:
# Area
# Surulere Jones        1.000000e+05
# Yaba Road             2.000000e+05
# Lekki Airport         3.500000e+05
# Lekki resort          6.000000e+05
# Epe chevron           6.000000e+05
#                           ...
# Lekki chevron         1.150000e+11
# Amuwo-Odofin Amuwo    1.700000e+11
# VI Victoria           2.500000e+11
# Apapa A               1.500000e+12
# Ikeja Opebi           1.600000e+12
# Name: Price, Length: 416, dtype: float64

# %%
df.groupby('Area').Price.min().sort_values(ascending = True) #Minimum price by Area in Ascending Order
# Out:
# Area
# Ikorodu Ikorodu     1.000000e+03
# Ikorodu Ijede       1.200000e+03
# VI Lagos            1.300000e+03
# VI Victoria         2.500000e+03
# Ajah Ogombo         8.000000e+03
#                         ...
# VGC Expressway      3.500000e+09
# VI                  3.500000e+09
# Isolo Expressway    3.500000e+09
# Ojo Victoria        4.000000e+09
# Badagry Coker       4.000000e+09
# Name: Price, Length: 416, dtype: float64

# %% [markdown]
# ### Question 8: Show the total count of records each area, where 'Price' is  more than 10 Billion. And how many such records are there?

# %%
df[df.Price > 10000000000]
# Out:
#            Date         Price            Pid  \
# 724  2021-01-03  2.500000e+10          H3814
# 2683 2021-01-14  6.000000e+10          G8456
# 2762 2021-01-14  8.500000e+10          G8244
# 3350 2021-01-17  8.000000e+10   26,322,G6546
# 3627 2021-01-17  2.500000e+11       10,G5390
# 4053 2021-01-19  7.500000e+10          G3783
# 4258 2021-01-22  8.500000e+10          G3186
# 4397 2021-01-22  5.000000e+10          F8455
# 4516 2021-01-23  2.100000e+10          E1505
# 4548 2021-01-23  9.500000e+10          G2205
# 4585 2021-01-23  2.500000e+10          G2074
# 5131 2021-01-25  1.500000e+12          F3405
# 5133 2021-01-25  1.100000e+10          F5450
# 5151 2021-01-25  1.500000e+10  15,6600,F9351
# 5913 2021-01-29  1.150000e+11       60,F6724
# 6325 2021-01-31  1.100000e+10          F4926
# 6438 2021-01-31  2.500000e+10          F4526
# 6643 2021-02-01  1.500000e+10          F3661
# 6815 2021-02-02  3.000000e+10       10,F3039
# 6956 2021-02-04  1.150000e+11       60,F2620
# ...

# %%
df[df.Price > 10000000000].Area.value_counts() #Answer
# Out:
# VI Victoria           11
# Lekki chevron          2
# Abule-Egba Abule       1
# Yaba Alagomeji         1
# Orile agege            1
# Ibeju-Lekki Ibeju      1
# Lekki Phase            1
# Ikoyi Bourdillon       1
# Lekki london           1
# Ajah estate            1
# Apapa A                1
# Apapa Can              1
# Apapa road             1
# Amuwo-Odofin Amuwo     1
# Ikeja Opebi            1
# Name: Area, dtype: int64
